# %% [markdown]
# #**Section 1: Prepare Data**

# %% [markdown]
# ##**Section 1.05: Import Data and Prepare Filepaths**

# %%
import json
import pandas as pd

# %%
file_paths = [
    '/content/BeatsPillPlus.json',
    '/content/JBLFlip5.json',
    '/content/JBLFlip6.json',
    '/content/BoseSoundlink.json',
    '/content/AnkerSoundCore2.json',
    '/content/OontZAngle3.json',
    '/content/SonySRSXB13.json',
    '/content/MusiBaby.json',
    '/content/Tribaby.json',
    '/content/MarshallEmbertonII.json'
]

loaded_data = {
    'BeatsPillPlus': '/content/BeatsPillPlus.json',
    'JBLFlip5': '/content/JBLFlip5.json',
    'JBLFlip6': '/content/JBLFlip6.json',
    'BoseSoundlink': '/content/BoseSoundlink.json',
    'AnkerSoundCore2': '/content/AnkerSoundCore2.json',
    'OontZAngle3': '/content/OontZAngle3.json',
    'SonySRSXB13': '/content/SonySRSXB13.json',
    'MusiBaby': '/content/MusiBaby.json',
    'Tribaby': '/content/Tribaby.json',
    'MarshallEmbertonII': '/content/MarshallEmbertonII.json'
}

# %% [markdown]
# ##**Section 1.1 Load Data**

# %%
for file_path in file_paths:
  with open(file_path, 'r') as file:
    loaded_data[file_path.split('/')[-1].split('.')[0]] = json.load(file)

# %% [markdown]
# ##**Section 1.2 Convert JSON To Pandas DataFrame**

# %%
# Initialize an empty list to store review data
reviews_data = []

# Initialize a counter to keep track of the total number of reviews
count = 0

def extract_reviews(product_name, data):
    global count  # Use the global count variable
    # Iterate over each result block in the results list
    for result in data['results']:
        asin = result['content']['asin']  # Get the ASIN of the product
        reviews = result['content']['reviews']  # Access the reviews list

        # Iterate over each review
        for review in reviews:
            count += 1
            # Extract review information and store it in a dictionary
            review_info = {
                'product_name': product_name,
                'review_id': review['id'],
                'asin': asin,
                'review_title': review['title'],
                'author': review['author'],
                'rating': review['rating'],
                'review_text': review['content'],
                'timestamp': review['timestamp'],
                'profile_id': review['profile_id'],
                'is_verified': review['is_verified'],
                'helpful_count': review.get('helpful_count', 0),
                'product_attributes': review.get('product_attributes', "")
            }

            reviews_data.append(review_info)

# Iterate through the loaded_data dictionary
for product_name, data in loaded_data.items():
    print(f"Processing {product_name}...")
    if isinstance(data, dict):
        extract_reviews(product_name, data)

# Print the total number of reviews processed
print(f"\n\nTotal number of reviews processed: {count}")

# Create a DataFrame from the reviews_data list
reviews_df = pd.DataFrame(reviews_data)

# Display the DataFrame
reviews_df.head()
# Out:
# Processing BeatsPillPlus...
# Processing JBLFlip5...
# Processing JBLFlip6...
# Processing BoseSoundlink...
# Processing AnkerSoundCore2...
# Processing OontZAngle3...
# Processing SonySRSXB13...
# Processing MusiBaby...
# Processing Tribaby...
# Processing MarshallEmbertonII...
#
#
# Total number of reviews processed: 740
#     product_name       review_id        asin  \
# 0  BeatsPillPlus  R1CSGCR2DCPPS2  B016QXV2QK
# 1  BeatsPillPlus   RPK8LMOBQ33B5  B016QXV2QK
# 2  BeatsPillPlus  R2DQAQ3RL2II2V  B016QXV2QK
# 3  BeatsPillPlus   RQJQ6PKGWO9PV  B016QXV2QK
# 4  BeatsPillPlus  R3430B3F39GCEC  B016QXV2QK
#
#                                         review_title              author  \
# 0  5.0 out of 5 stars The best speaker I own to d...        Nicole lopez
# 1  5.0 out of 5 stars Yes! It is worth it!!!! Buy...  NYC WDSTK JENNIFER
# 2  5.0 out of 5 stars Even better than our old ja...               Chris
# 3                   4.0 out of 5 stars Amazing sound     Amazon Customer
# 4                    4.0 out of 5 stars Works great!                 BSP
#
#    rating                                        review_text  \
# 0       5  I already have one that my ex bought me 13 yea...
# 1       5  Wow! That could be my whole review but just to...
# 2       5  We have a jambox original that we’ve had forev...
# 3       4  I was looking for a good speaker that not only...
# 4       4  Part of my job includes giving presentations o...
#
#                                          timestamp  \
# 0     Reviewed in the United States April 18, 2023
# 1   Reviewed in the United States October 18, 2020
# 2      Reviewed in the United States July 24, 2020
# 3  Reviewed in the United States November 27, 2016
# 4    Reviewed in the United States January 2, 2020
#
#                      profile_id  is_verified  helpful_count product_attributes
# 0  AEHTY62RUJBKU7VY34I3UYQDN7IA         True              2       Color: Black
# 1  AHIK4P52QYCJEI3C7ZKDEP5E6QSA         True              2       Color: White
# 2  AEVQN5XRWKZRQAYNJNHKACH5EOMQ         True              0       Color: Black
# 3  AHLS3IUUEKAIK42VFWMWZN2GHQAA         True             18       Color: White
# 4  AHISN46CYDOATATCIHYVMSZLCZHA         True              2       Color: White

# %%
len(reviews_df)
# Out:
# 740

# %% [markdown]
# #**Section 2: Clean Dataset**

# %% [markdown]
# ##**Section 2.1: Import Nessecary Packages**

# %%
import numpy as np

# %% [markdown]
# ##**Section 2.2: Drop Null (Empty) Values**

# %%
# Detect Null Values
reviews_df.isnull().sum()

# Drop Null
reviews_df.dropna(inplace=True)

print(len(reviews_df))
# Out:
# 740

# %% [markdown]
# ##**Section 2.2: Identify And Handle Outliers**

# %%
# Ensure ratings are within the expected range
reviews_df = reviews_df[(reviews_df['rating'] >= 1) & (reviews_df['rating'] <= 5)]

# Identify outliers in helpful_count using the IQR (Interquartile Range) method
Q1 = reviews_df['helpful_count'].quantile(0.25)
Q3 = reviews_df['helpful_count'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers in helpful_count
reviews_df = reviews_df[(reviews_df['helpful_count'] >= lower_bound) & (reviews_df['helpful_count'] <= upper_bound)]

# %%
# Check for categorical columns that need conversion
print("Data types before conversion:\n", reviews_df.dtypes)

# Convert categorical column 'product_attributes' to numerical using one-hot encoding
reviews_df = pd.concat([reviews_df, pd.get_dummies(reviews_df['product_attributes'], prefix='attr')], axis=1)

# Optionally, you may drop the original 'product_attributes' column
reviews_df.drop(columns=['product_attributes'], inplace=True)
# Out:
# Data types before conversion:
#  product_name          object
# review_id             object
# asin                  object
# review_title          object
# author                object
# rating                 int64
# review_text           object
# timestamp             object
# profile_id            object
# is_verified             bool
# helpful_count          int64
# product_attributes    object
# dtype: object

# %%
# Review the cleaned dataset
print("What Product would you like to review?")
print(reviews_df['product_name'].unique())

inp = input()

reviews_df[reviews_df['product_name'] == inp]
# Out:
# What Product would you like to review?
# ['BeatsPillPlus' 'JBLFlip5' 'JBLFlip6' 'BoseSoundlink' 'AnkerSoundCore2'
# 71  AF5BSF3Z6NEQ2PGIQ74OOJ7SOECQ         True  ...                    False
# 72  AHRUGT5EYE4FUSPVKFNIUVUNLOGQ         True  ...                    False
# 74  AG3CDJPAE6ZM4GX4VIPLJSPJUFTQ         True  ...                    False
# 75  AERPHNLUAZYIRSKGXMMABPUZD4XQ         True  ...                    False
# 76  AHMQZS2FKS4ZDFDDQ35J2XVC7NMQ         True  ...                    False
# 77  AGDFNK7F2LVP7QU25AI2SEMNDDWQ         True  ...                    False
# 78  AF7GGVPPINLMA4I7V5JRBHXTQQYA         True  ...                    False
#
#     attr_Color: WhiteStyle: Flip 6  attr_Style: Flip 5Color: Black  \
# 2                            False                           False
# 7                            False                           False
# 8                            False                           False
# 9                            False                           False
# 12                           False                           False
# 15                           False                           False
# 18                           False                           False
# 19                           False                           False
# 20                           False                           False
# 21                           False                           False
# 22                           False                           False
# 23                           False                           False
# 25                           False                           False
# 26                           False                           False
# 27                           False                           False
# 28                           False                           False
# 29                           False                           False
# 31                           False                           False
# 32                           False                           False
# 33                           False                           False
# 34                           False                           False
# 35                           False                           False
# 40                           False                           False
# 41                           False                           False
# 42                           False                           False
# 45                           False                           False
# 46                           False                           False
# 47                           False                           False
# 48                           False                           False
# 49                           False                           False
# 50                           False                           False
# 51                           False                           False
# 52                           False                           False
# 53                           False                           False
# 54                           False                           False
# 56                           False                           False
# 57                           False                           False
# 59                           False                           False
# 61                           False                           False
# 62                           False                           False
# 63                           False                           False
# 64                           False                           False
# 66                           False                           False
# 67                           False                           False
# 68                           False                           False
# 69                           False                           False
# 71                           False                           False
# 72                           False                           False
# 74                           False                           False
# 75                           False                           False
# 76                           False                           False
# 77                           False                           False
# 78                           False                           False
#
#     attr_Style: Flip 5Color: Eco Green  attr_Style: Flip 5Color: Gray  \
# 2                                False                          False
# 7                                False                          False
# 8                                False                          False
# 9                                False                          False
# 12                               False                          False
# 15                               False                          False
# 18                               False                          False
# 19                               False                          False
# 20                               False                          False
# 21                               False                          False
# 22                               False                          False
# 23                               False                          False
# 25                               False                          False
# 26                               False                          False
# 27                               False                          False
# 28                               False                          False
# 29                               False                          False
# 31                               False                          False
# 32                               False                          False
# 33                               False                          False
# 34                               False                          False
# 35                               False                          False
# 40                               False                          False
# 41                               False                          False
# 42                               False                          False
# 45                               False                          False
# 46                               False                          False
# 47                               False                          False
# 48                               False                          False
# 49                               False                          False
# 50                               False                          False
# 51                               False                          False
# 52                               False                          False
# 53                               False                          False
# 54                               False                          False
# 56                               False                          False
# 57                               False                          False
# 59                               False                          False
# 61                               False                          False
# 62                               False                          False
# 63                               False                          False
# 64                               False                          False
# 66                               False                          False
# 67                               False                          False
# 68                               False                          False
# 69                               False                          False
# 71                               False                          False
# 72                               False                          False
# 74                               False                          False
# 75                               False                          False
# 76                               False                          False
# 77                               False                          False
# 78                               False                          False
#
#     attr_Style: Flip 5Color: Green  attr_Style: Flip 5Color: Pink  \
# 2                            False                          False
# 7                            False                          False
# 8                            False                          False
# 9                            False                          False
# 12                           False                          False
# 15                           False                          False
# 18                           False                          False
# 19                           False                          False
# 20                           False                          False
# 21                           False                          False
# 22                           False                          False
# 23                           False                          False
# 25                           False                          False
# 26                           False                          False
# 27                           False                          False
# 28                           False                          False
# 29                           False                          False
# 31                           False                          False
# 32                           False                          False
# 33                           False                          False
# 34                           False                          False
# 35                           False                          False
# 40                           False                          False
# 41                           False                          False
# 42                           False                          False
# 45                           False                          False
# 46                           False                          False
# 47                           False                          False
# 48                           False                          False
# 49                           False                          False
# 50                           False                          False
# 51                           False                          False
# 52                           False                          False
# 53                           False                          False
# 54                           False                          False
# 56                           False                          False
# 57                           False                          False
# 59                           False                          False
# 61                           False                          False
# 62                           False                          False
# 63                           False                          False
# 64                           False                          False
# 66                           False                          False
# 67                           False                          False
# 68                           False                          False
# 69                           False                          False
# 71                           False                          False
# 72                           False                          False
# 74                           False                          False
# 75                           False                          False
# 76                           False                          False
# 77                           False                          False
# 78                           False                          False
#
#     attr_Style: Flip 5Color: Red  attr_Style: Flip 5Color: Teal  \
# 2                          False                          False
# 7                          False                          False
# 8                          False                          False
# 9                          False                          False
# 12                         False                          False
# 15                         False                          False
# 18                         False                          False
# 19                         False                          False
# 20                         False                          False
# 21                         False                          False
# 22                         False                          False
# 23                         False                          False
# 25                         False                          False
# 26                         False                          False
# 27                         False                          False
# 28                         False                          False
# 29                         False                          False
# 31                         False                          False
# 32                         False                          False
# 33                         False                          False
# 34                         False                          False
# 35                         False                          False
# 40                         False                          False
# 41                         False                          False
# 42                         False                          False
# 45                         False                          False
# 46                         False                          False
# 47                         False                          False
# 48                         False                          False
# 49                         False                          False
# 50                         False                          False
# 51                         False                          False
# 52                         False                          False
# 53                         False                          False
# 54                         False                          False
# 56                         False                          False
# 57                         False                          False
# 59                         False                          False
# 61                         False                          False
# 62                         False                          False
# 63                         False                          False
# 64                         False                          False
# 66                         False                          False
# 67                         False                          False
# 68                         False                          False
# 69                         False                          False
# 71                         False                          False
# 72                         False                          False
# 74                         False                          False
# 75                         False                          False
# 76                         False                          False
# 77                         False                          False
# 78                         False                          False
#
#     attr_Style: Flip 5Color: White
# 2                            False
# 7                            False
# 8                            False
# 9                            False
# 12                           False
# 15                           False
# 18                           False
# 19                           False
# 20                           False
# 21                           False
# 22                           False
# 23                           False
# 25                           False
# 26                           False
# 27                           False
# 28                           False
# 29                           False
# 31                           False
# 32                           False
# 33                           False
# 34                           False
# 35                           False
# 40                           False
# 41                           False
# 42                           False
# 45                           False
# 46                           False
# 47                           False
# 48                           False
# 49                           False
# 50                           False
# 51                           False
# 52                           False
# 53                           False
# 54                           False
# 56                           False
# 57                           False
# 59                           False
# 61                           False
# 62                           False
# 63                           False
# 64                           False
# 66                           False
# 67                           False
# 68                           False
# 69                           False
# 71                           False
# 72                           False
# 74                           False
# 75                           False
# 76                           False
# 77                           False
# 78                           False
#
# [53 rows x 51 columns]

# %%
reviews_df.describe()
# Out:
#            rating  helpful_count
# count  593.000000          593.0
# mean     4.809444            0.0
# std      0.441640            0.0
# min      1.000000            0.0
# 25%      5.000000            0.0
# 50%      5.000000            0.0
# 75%      5.000000            0.0
# max      5.000000            0.0

# %%
reviews_df.to_csv('cleaned_amazon_reviews.csv', index = False)
